# %%
t=6,7,9
type(t)
# Out:
# tuple

# %%
s={}
type(s)
# Out:
# dict

# %%
# how to remove duplicates 
l=[9,0,67,0,8,8]
a=set(l)
a
# Out:
# {0, 8, 9, 67}

# %%
b={89,90,6,'p',78,456,9,(2,3)}
b
# Out:
# {(2, 3), 456, 6, 78, 89, 9, 90, 'p'}

# %%
c=[89,90,6,'p',78,456,9,(2,3)]
c
# Out:
# [89, 90, 6, 'p', 78, 456, 9, (2, 3)]

# %%
s={9,9,0}
s.update([7,0,9])
s
# Out:
# {0, 7, 9}

# %%
s.add((3,0))
s
# Out:
# {(3, 0), 0, 3, 7, 9}

# %%
s.remove(3)
s
# Out:
# {(3, 0), 7, 9}

# %%
s.discard(70)
s
# Out:
# {(3, 0)}

# %%
s.pop()
s
# Out:
# set()

# %%
l=[7,9,80,98]
l.pop(0)
l
# Out:
# [9, 80, 98]

# %%
l.remove(9)
l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 l.remove(9)
#       2 l
#
# ValueError: list.remove(x): x not in list
